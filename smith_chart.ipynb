# %% [markdown]
# <a href="https://colab.research.google.com/github/sid-nadella12/IC-CAP-python/blob/master/smith_chart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install scikit-rf
import skrf as rf

ntwk = rf.Network('HA9.s2p')
ntwk.plot_s_smith()
